# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 1. Charger les données
data = pd.read_csv('air_quality_dataset.csv')

# 2. Sélectionner les caractéristiques (X) et la cible (y)
# Supposons que 'Qualité de l'air' est la variable cible (0 ou 1)
X = data[['CO2 (ppm)', 'Température (°C)', 'Humidité (%)']]  # Variables indépendantes
y = data['Qualité de l\'air']  # Variable dépendante (cible)

# 3. Normaliser les données (recommandé pour k-NN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 4. Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 5. Créer et entraîner le modèle k-NN
k = 4  # Nombre de voisins (vous pouvez ajuster cette valeur)
model = KNeighborsClassifier(n_neighbors=k)
model.fit(X_train, y_train)

# 6. Faire des prédictions sur les données de test
y_pred = model.predict(X_test)

# 7. Évaluer les performances du modèle
# 7.1. Précision (Accuracy)
accuracy = accuracy_score(y_test, y_pred)
print(f"Précision (Accuracy) : {accuracy}")

# 7.2. Matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matrice de confusion :")
print(conf_matrix)

# 7.3. Rapport de classification
class_report = classification_report(y_test, y_pred)
print("Rapport de classification :")
print(class_report)
# Out:
# Précision (Accuracy) : 0.95
# Matrice de confusion :
# [[18  0]
#  [ 1  1]]
# Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        18
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.95        20
#    macro avg       0.97      0.75      0.82        20
# weighted avg       0.95      0.95      0.94        20

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# 1. Créer le modèle k-NN de base
knn = KNeighborsClassifier()

# 2. Définir les hyperparamètres à tester
parameters = {'n_neighbors': [2, 3, 4, 5, 6, 7]}

# 3. Utiliser GridSearchCV pour trouver les meilleurs hyperparamètres
model = GridSearchCV(knn, parameters, cv=5)  # cv=5 pour une validation croisée à 5 plis
model.fit(X_train, y_train)

# 4. Afficher les meilleurs hyperparamètres
best_params = model.best_params_
print(f"Meilleurs hyperparamètres : {best_params}")

# 5. Créer un nouveau modèle k-NN avec les meilleurs hyperparamètres
best_k = best_params['n_neighbors']  # Récupérer la meilleure valeur de k
best_knn = KNeighborsClassifier(n_neighbors=best_k)

# 6. Entraîner le modèle avec les meilleurs hyperparamètres
best_knn.fit(X_train, y_train)

# 7. Faire des prédictions sur les données de test
y_pred = best_knn.predict(X_test)

# 8. Évaluer les performances du modèle
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 8.1. Précision (Accuracy)
accuracy = accuracy_score(y_test, y_pred)
print(f"Précision (Accuracy) : {accuracy}")

# 8.2. Matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matrice de confusion :")
print(conf_matrix)

# 8.3. Rapport de classification
class_report = classification_report(y_test, y_pred)
print("Rapport de classification :")
print(class_report)
# Out:
# Meilleurs hyperparamètres : {'n_neighbors': 2}
# Précision (Accuracy) : 0.95
# Matrice de confusion :
# [[18  0]
#  [ 1  1]]
# Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        18
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.95        20
#    macro avg       0.97      0.75      0.82        20
# weighted avg       0.95      0.95      0.94        20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sélectionner les deux caractéristiques pour l'entraînement
X_train_vis = X_train[:, :2]  # Utiliser les deux premières caractéristiques (CO2 et Température)

# Ré-entraîner le modèle k-NN sur les deux caractéristiques
best_knn.fit(X_train_vis, y_train)
# 2. Créer une grille pour visualiser les décisions du modèle
x_min, x_max = X_vis[:, 0].min() - 1, X_vis[:, 0].max() + 1
y_min, y_max = X_vis[:, 1].min() - 1, X_vis[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),  # Grille fine pour une visualisation lisse
                     np.arange(y_min, y_max, 0.01))

# 3. Prédire les classes pour chaque point de la grille
Z = best_knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# 4. Tracer les régions de décision
plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.Paired)  # Tracer les régions de décision
plt.scatter(X_vis[:, 0], X_vis[:, 1], c=y_test, edgecolors='k', cmap=plt.cm.Paired)  # Tracer les points de test
plt.xlabel('CO2 (ppm)')
plt.ylabel('Température (°C)')
plt.title('Régions de décision et classes prédites par k-NN')
plt.colorbar(label='Classe')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 14
#      10 xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),  # Grille fine pour une visualisation lisse
#      11                      np.arange(y_min, y_max, 0.01))
#      13 # 3. Prédire les classes pour chaque point de la grille
# ---> 14 Z = best_knn.predict(np.c_[xx.ravel(), yy.ravel()])
#      15 Z = Z.reshape(xx.shape)
#      17 # 4. Tracer les régions de décision
#
# File c:\Users\21620\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:271, in KNeighborsClassifier.predict(self, X)
#     268         return self.classes_[np.argmax(probabilities, axis=1)]
#     269     # In that case, we do not need the distances to perform
#     270     # the weighting so we do not compute them.
# --> 271     neigh_ind = self.kneighbors(X, return_distance=False)
#     272     neigh_dist = None
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Sélectionner deux caractéristiques pour la visualisation (par exemple, CO2 et Température)
X_vis = X_test[:, :2]  # Utiliser les deux premières caractéristiques (CO2 et Température)

# 2. Créer une grille pour visualiser les décisions du modèle
x_min, x_max = X_vis[:, 0].min() - 1, X_vis[:, 0].max() + 1
y_min, y_max = X_vis[:, 1].min() - 1, X_vis[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),  # Grille fine pour une visualisation lisse
                     np.arange(y_min, y_max, 0.01))

# 3. Prédire les classes pour chaque point de la grille
# Utiliser uniquement les deux caractéristiques pour la prédiction
Z = best_knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# 4. Tracer les régions de décision
plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.Paired)  # Tracer les régions de décision
plt.scatter(X_vis[:, 0], X_vis[:, 1], c=y_test, edgecolors='k', cmap=plt.cm.Paired)  # Tracer les points de test
plt.xlabel('CO2 (ppm)')
plt.ylabel('Température (°C)')
plt.title('Régions de décision et classes prédites par k-NN')
plt.colorbar(label='Classe')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 15
#      10 xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),  # Grille fine pour une visualisation lisse
#      11                      np.arange(y_min, y_max, 0.01))
#      13 # 3. Prédire les classes pour chaque point de la grille
#      14 # Utiliser uniquement les deux caractéristiques pour la prédiction
# ---> 15 Z = best_knn.predict(np.c_[xx.ravel(), yy.ravel()])
#      16 Z = Z.reshape(xx.shape)
#      18 # 4. Tracer les régions de décision
#
# File c:\Users\21620\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:271, in KNeighborsClassifier.predict(self, X)
#     268         return self.classes_[np.argmax(probabilities, axis=1)]
#     269     # In that case, we do not need the distances to perform
#     270     # the weighting so we do not compute them.
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calcul des métriques
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Affichage des résultats
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.9500
# Precision: 0.9526
# Recall: 0.9500
# F1-score: 0.9423
