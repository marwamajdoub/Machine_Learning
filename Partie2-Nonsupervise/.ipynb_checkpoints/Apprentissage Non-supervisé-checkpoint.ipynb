# %% [markdown]
# <a href="https://colab.research.google.com/github/MachineLearnia/Python-Machine-Learning/blob/master/24%20-%20Sklearn%20%3A%20Apprentissage%20Non-supervis%C3%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Partie 2: Modèles de Machine Learning d’Apprentissage non-supervisé

# %%
import numpy as np
from sklearn.datasets import make_blobs

# %% [markdown]
# ## 1. K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
import matplotlib.pyplot as plt

# %%
# Génération de données
X, y = make_blobs(n_samples=100, centers=3, cluster_std=0.4, random_state=0)# fonction qui genere les données sous forme de cluster, X contient les coordonnes (X,y) et y les etiquettes de chaqie cluster 
plt.scatter(X[:,0], X[:,1])#afficher les 3 cluster spus forme de nuage (scatter=nuage)

# %%
model = KMeans(n_clusters=3)# creation du modele
model.fit(X)#entrainement du modele , apprend des aclusters sur X
model.predict(X)#pour chaque point x aassigner le clauster le plus proche
plt.scatter(X[:,0], X[:,1], c=model.predict(X))
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c='r')
model.score(X)
# Out:
# -30.870531280140675

# %% [markdown]
# ### Elbow Method

# %%
inertia = []
K_range = range(1, 20)
for k in K_range:
    model = KMeans(n_clusters=k).fit(X)
    inertia.append(model.inertia_)

plt.plot(K_range, inertia)
plt.xlabel('nombre de clusters')
plt.ylabel('Cout du modele (Inertia)')
# Out:
# Text(0, 0.5, 'Cout du modele (Inertia)')

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
Y= iris.target
X = iris.data[:, :2]

# %%
plt.scatter(X[:,0], X[:,1], c=iris.target, cmap='gist_rainbow')
plt.xlabel('Speal Length', fontsize=18)
plt.ylabel('Sepal Width', fontsize=18)
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data[:, :2] , iris.target, test_size=0.2, random_state=0)
model = KMeans(n_clusters=3)
model.fit(X_train)
y_labels_train = model.labels_
y_labels_test  = model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=model.predict(X_test))
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c='r')
model.score(X)
# Out:
# -38.19471380288397

# %% [markdown]
# ## 2. Detection d'anomalies avec Isolation Forest

# %%
from sklearn.ensemble import IsolationForest
#Isolation Forest est un algorithme de détection d'anomalies qui détecte les points rares ou aberrants en les isolant dans des arbres de décision.
#Isolation : Les anomalies sont isolées plus rapidement car elles sont éloignées des autres points.
#Méthode par arbres : L'algorithme construit plusieurs arbres de décision pour diviser les données de manière aléatoire.
#Score d'anomalie : Les points difficiles à isoler sont considérés comme normaux, tandis que ceux qui sont isolés rapidement sont des anomalies.
#Il est rapide et efficace pour détecter des anomalies, surtout dan

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=50, centers=1, cluster_std=0.1, random_state=0)#generates 50 data points (n_samples=50).
X[-1,:] = np.array([2.25, 5])#The points belong to one cluster (centers=1), meaning all points are centered around a single location.


plt.scatter(X[:,0], X[:, 1])

# %%
model = IsolationForest(contamination=0.01)
model.fit(X)

plt.scatter(X[:,0], X[:, 1], c=model.predict(X))#The contamination=0.01 parameter means the model expects 1% of the data to be outliers (anomalies). This is used to guide the model in detecting anomalous point

# %% [markdown]
# ### Application : Digits Outliers

# %%
from sklearn.datasets import load_digits

digits = load_digits()
images = digits.images
X = digits.data
y = digits.target
print(X.shape)

plt.imshow(images[0])
# Out:
# (1797, 64)

# %%
model = IsolationForest(random_state=0, contamination=0.02)
model.fit(X)
outliers = model.predict(X) == -1

plt.figure(figsize=(12, 3))
for i in range(10):
  plt.subplot(1, 10, i+1)
  plt.imshow(images[outliers][i])
  plt.title(y[outliers][i]) #le 10 anomalies sont detectees et affiches avec leur etiquettes

# %% [markdown]
# ## 3. Reduction de dimension avec PCA

# %% [markdown]
# ### Visualisation 2D

# %%
from sklearn.decomposition import PCA

model = PCA(n_components=2)
x_pca=model.fit_transform(X)
model.fit_transform(X).shape
X.shape
# Out:
# (1797, 64)

# %%
plt.scatter(x_pca[:,0], x_pca[:,1], c=y)
plt.colorbar()

# %%
model.components_.shape
# Out:
# (2, 64)

# %%
plt.figure()
plt.xlim(-30, 30)
plt.ylim(-30, 30)

for i in range(100):
    plt.text(x_pca[i,0], x_pca[i,1], str(y[i]))

# %% [markdown]
# ### Compression de données

# %%
n_dims = X.shape[1]
model = PCA(n_components=n_dims)
model.fit(X)

variances = model.explained_variance_ratio_

meilleur_dims = np.argmax(np.cumsum(variances) > 0.90)


plt.bar(range(n_dims), np.cumsum(variances))
plt.hlines(0.90, 0, meilleur_dims, colors='r')
plt.vlines(meilleur_dims, 0, 0.90, colors='r')

# %%
model = PCA(n_components=0.99)
model.fit(X)
# Out:
# PCA(n_components=0.99)

# %%
X_compress = model.fit_transform(X)
X_decompress = model.inverse_transform(X_compress)

plt.subplot(1, 2, 1)
plt.imshow(X[0,:].reshape((8,8)), cmap='gray')
plt.title('originel')
plt.subplot(1, 2, 2)
plt.imshow(X_decompress[0,:].reshape((8,8)), cmap='gray')
plt.title('Compressé')
# Out:
# Text(0.5, 1.0, 'Compressé')
